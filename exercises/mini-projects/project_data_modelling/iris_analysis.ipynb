# %% [markdown]
# # Import data
# Lets pull in the data and display it. We have 4 feature columns and one target column called `target`.

# %%
from sklearn.datasets import load_iris
import pandas as pd

iris = load_iris(as_frame=True)  # set as_frame=False if older scikit-learn
df = iris.data.copy()  # X as DataFrame
df['target'] = iris.target
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %% [markdown]
# # High level Analysis
# Lets check for nulls and examine the mean, median, etc for the different features across the different targets.

# %%
from IPython.display import display

# Check for missing values
print("Null values per column:")
print(df.isna().sum())

# Overall descriptive statistics
print("\nOverall descriptive statistics (features):")
display(df.describe().T)

# Select feature columns
features = df.columns.drop('target')

# Aggregate stats by target
group_stats = df.groupby('target')[features].agg(['count', 'mean', 'median', 'std', 'min', 'max'])
# Map numeric target to class names if `iris` is available
try:
    group_stats.index = group_stats.index.map(lambda i: iris.target_names[i])
except Exception:
    pass

print("\nAggregate statistics by target:")
display(group_stats)

# Interquartile range (IQR) by target
iqr = df.groupby('target')[features].agg(lambda x: x.quantile(0.75) - x.quantile(0.25))
try:
    iqr.index = iqr.index.map(lambda i: iris.target_names[i])
except Exception:
    pass

print("\nInterquartile range (IQR) by target:")
display(iqr)
# Out:
# Null values per column:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# target               0
# dtype: int64
#
# Overall descriptive statistics (features):
#                    count      mean       std  min  25%   50%  75%  max
# sepal length (cm)  150.0  5.843333  0.828066  4.3  5.1  5.80  6.4  7.9
# sepal width (cm)   150.0  3.057333  0.435866  2.0  2.8  3.00  3.3  4.4
# petal length (cm)  150.0  3.758000  1.765298  1.0  1.6  4.35  5.1  6.9
# petal width (cm)   150.0  1.199333  0.762238  0.1  0.3  1.30  1.8  2.5
# target             150.0  1.000000  0.819232  0.0  0.0  1.00  2.0  2.0
# Aggregate statistics by target:
#            sepal length (cm)                                    \
#                        count   mean median       std  min  max
# target
# setosa                    50  5.006    5.0  0.352490  4.3  5.8
# versicolor                50  5.936    5.9  0.516171  4.9  7.0
# virginica                 50  6.588    6.5  0.635880  4.9  7.9
#
#            sepal width (cm)                          ... petal length (cm)  \
#                       count   mean median       std  ...            median
# target                                               ...
# setosa                   50  3.428    3.4  0.379064  ...              1.50
# versicolor               50  2.770    2.8  0.313798  ...              4.35
# virginica                50  2.974    3.0  0.322497  ...              5.55
#
#                                petal width (cm)                               \
#                  std  min  max            count   mean median       std  min
# target
# setosa      0.173664  1.0  1.9               50  0.246    0.2  0.105386  0.1
# versicolor  0.469911  3.0  5.1               50  1.326    1.3  0.197753  1.0
# virginica   0.551895  4.5  6.9               50  2.026    2.0  0.274650  1.4
#
#
#             max
# target
# setosa      0.6
# versicolor  1.8
# virginica   2.5
#
# [3 rows x 24 columns]
# Interquartile range (IQR) by target:
#             sepal length (cm)  sepal width (cm)  petal length (cm)  \
# target
# setosa                  0.400             0.475              0.175
# versicolor              0.700             0.475              0.600
# virginica               0.675             0.375              0.775
#
#             petal width (cm)
# target
# setosa                   0.1
# versicolor               0.3
# virginica                0.5

# %% [markdown]
# # Plots
# Lets examine how the data looks. Use copilot to generate plots of the data, e.g. use PCA and colour by target.

# %%
from sklearn.decomposition import PCA
import numpy as np

import matplotlib.pyplot as plt

# Prepare data for PCA
X = df.drop('target', axis=1)
y = df['target']

# Apply PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

# Create plot
plt.figure(figsize=(8, 6))
scatter = plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y, cmap='viridis', alpha=0.7, s=100)
plt.xlabel(f'PC1 ({pca.explained_variance_ratio_[0]:.2%} variance)')
plt.ylabel(f'PC2 ({pca.explained_variance_ratio_[1]:.2%} variance)')
plt.title('PCA of Iris Dataset')
plt.colorbar(scatter, label='Target')
plt.grid(alpha=0.3)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       4 import matplotlib.pyplot as plt
#       6 # Prepare data for PCA
# ----> 7 X = df.drop('target', axis=1)
#       8 y = df['target']
#      10 # Apply PCA
#
# NameError: name 'df' is not defined

# %% [markdown]
# # Optional: Modelling
# Use a model for classification from sklearn to try and predict the target based on the features or instead, discuss with copilot what model you can use in the chat!
